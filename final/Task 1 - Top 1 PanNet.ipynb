# %%
# !nvidia-smi
# Out:
# Thu Dec 17 10:37:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/WenmuZhou/PAN.pytorch
# Out:
# Cloning into 'PAN.pytorch'...
# remote: Enumerating objects: 413, done.
# remote: Total 413 (delta 0), reused 0 (delta 0), pack-reused 413
# Receiving objects: 100% (413/413), 1.82 MiB | 1.72 MiB/s, done.
# Resolving deltas: 100% (213/213), done.

# %%
# !pip install torch==1.4.0+cu92 torchvision==0.5.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install pyclipper
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4.0+cu92
#   Downloading https://download.pytorch.org/whl/cu92/torch-1.4.0%2Bcu92-cp36-cp36m-linux_x86_64.whl (640.5MB)
#      |████████████████████████████████| 640.6MB 15kB/s
# Collecting torchvision==0.5.0+cu92
#   Downloading https://download.pytorch.org/whl/cu92/torchvision-0.5.0%2Bcu92-cp36-cp36m-linux_x86_64.whl (3.9MB)
#      |████████████████████████████████| 4.0MB 38.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu92) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu92) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu92) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.4.0+cu92 torchvision-0.5.0+cu92
# Collecting pyclipper
#   Downloading https://files.pythonhosted.org/packages/e3/82/eb4d65b8a7f53e83157d54b200c97e1d2085e48664f6f41af49155f6f9dd/pyclipper-1.2.0-cp36-cp36m-manylinux1_x86_64.whl (126kB)
#      |████████████████████████████████| 133kB 4.0MB/s
# Installing collected packages: pyclipper
# Successfully installed pyclipper-1.2.0

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# https://medium.com/@orhanakal/install-gcc-4-9-and-g-4-9-on-ubuntu-18-04-6888b92e5bab
# !mkdir ~/Downloads/gcc-4.9-deb && cd ~/Downloads/gcc-4.9-deb

# !wget http://launchpadlibrarian.net/247707088/libmpfr4_3.1.4-1_amd64.deb
# !wget http://launchpadlibrarian.net/253728424/libasan1_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728426/libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728314/gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728399/cpp-4.9_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728404/gcc-4.9_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728432/libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# !wget http://launchpadlibrarian.net/253728401/g++-4.9_4.9.3-13ubuntu2_amd64.deb

# !sudo dpkg -i gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i libmpfr4_3.1.4-1_amd64.deb
# !sudo dpkg -i libasan1_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i cpp-4.9_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i gcc-4.9_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# !sudo dpkg -i g++-4.9_4.9.3-13ubuntu2_amd64.deb
# Out:
# mkdir: cannot create directory ‘/root/Downloads/gcc-4.9-deb’: No such file or directory
# --2020-12-17 10:40:05--  http://launchpadlibrarian.net/247707088/libmpfr4_3.1.4-1_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.229, 91.189.89.228, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.229|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190628 (186K) [application/x-debian-package]
# Saving to: ‘libmpfr4_3.1.4-1_amd64.deb’
#
# libmpfr4_3.1.4-1_am 100%[===================>] 186.16K   269KB/s    in 0.7s
#
# 2020-12-17 10:40:07 (269 KB/s) - ‘libmpfr4_3.1.4-1_amd64.deb’ saved [190628/190628]
#
# --2020-12-17 10:40:07--  http://launchpadlibrarian.net/253728424/libasan1_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.229, 91.189.89.228, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.229|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 196624 (192K) [application/x-debian-package]
# Saving to: ‘libasan1_4.9.3-13ubuntu2_amd64.deb’
#
# libasan1_4.9.3-13ub 100%[===================>] 192.02K   280KB/s    in 0.7s
#
# 2020-12-17 10:40:08 (280 KB/s) - ‘libasan1_4.9.3-13ubuntu2_amd64.deb’ saved [196624/196624]
#
# --2020-12-17 10:40:08--  http://launchpadlibrarian.net/253728426/libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.229, 91.189.89.228, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.229|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2072504 (2.0M) [application/x-debian-package]
# Saving to: ‘libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb’
#
# libgcc-4.9-dev_4.9. 100%[===================>]   1.98M  1.23MB/s    in 1.6s
#
# 2020-12-17 10:40:10 (1.23 MB/s) - ‘libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb’ saved [2072504/2072504]
#
# --2020-12-17 10:40:10--  http://launchpadlibrarian.net/253728314/gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.228, 91.189.89.229, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15290 (15K) [application/x-debian-package]
# Saving to: ‘gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb’
#
# gcc-4.9-base_4.9.3- 100%[===================>]  14.93K  60.9KB/s    in 0.2s
#
# 2020-12-17 10:40:11 (60.9 KB/s) - ‘gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb’ saved [15290/15290]
#
# --2020-12-17 10:40:12--  http://launchpadlibrarian.net/253728399/cpp-4.9_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.228, 91.189.89.229, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4971992 (4.7M) [application/x-debian-package]
# Saving to: ‘cpp-4.9_4.9.3-13ubuntu2_amd64.deb’
#
# cpp-4.9_4.9.3-13ubu 100%[===================>]   4.74M  2.36MB/s    in 2.0s
#
# 2020-12-17 10:40:14 (2.36 MB/s) - ‘cpp-4.9_4.9.3-13ubuntu2_amd64.deb’ saved [4971992/4971992]
#
# --2020-12-17 10:40:14--  http://launchpadlibrarian.net/253728404/gcc-4.9_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.228, 91.189.89.229, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5441772 (5.2M) [application/x-debian-package]
# Saving to: ‘gcc-4.9_4.9.3-13ubuntu2_amd64.deb’
#
# gcc-4.9_4.9.3-13ubu 100%[===================>]   5.19M  2.60MB/s    in 2.0s
#
# 2020-12-17 10:40:17 (2.60 MB/s) - ‘gcc-4.9_4.9.3-13ubuntu2_amd64.deb’ saved [5441772/5441772]
#
# --2020-12-17 10:40:17--  http://launchpadlibrarian.net/253728432/libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.228, 91.189.89.229, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1125834 (1.1M) [application/x-debian-package]
# Saving to: ‘libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb’
#
# libstdc++-4.9-dev_4 100%[===================>]   1.07M   746KB/s    in 1.5s
#
# 2020-12-17 10:40:19 (746 KB/s) - ‘libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb’ saved [1125834/1125834]
#
# --2020-12-17 10:40:19--  http://launchpadlibrarian.net/253728401/g++-4.9_4.9.3-13ubuntu2_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 91.189.89.228, 91.189.89.229, 2001:67c:1560:8003::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|91.189.89.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20984066 (20M) [application/x-debian-package]
# Saving to: ‘g++-4.9_4.9.3-13ubuntu2_amd64.deb’
#
# g++-4.9_4.9.3-13ubu 100%[===================>]  20.01M  6.61MB/s    in 3.0s
#
# 2020-12-17 10:40:23 (6.61 MB/s) - ‘g++-4.9_4.9.3-13ubuntu2_amd64.deb’ saved [20984066/20984066]
#
# Selecting previously unselected package gcc-4.9-base:amd64.
# (Reading database ... 144865 files and directories currently installed.)
# Preparing to unpack gcc-4.9-base_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking gcc-4.9-base:amd64 (4.9.3-13ubuntu2) ...
# Setting up gcc-4.9-base:amd64 (4.9.3-13ubuntu2) ...
# Selecting previously unselected package libmpfr4:amd64.
# (Reading database ... 144872 files and directories currently installed.)
# Preparing to unpack libmpfr4_3.1.4-1_amd64.deb ...
# Unpacking libmpfr4:amd64 (3.1.4-1) ...
# Setting up libmpfr4:amd64 (3.1.4-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Selecting previously unselected package libasan1:amd64.
# (Reading database ... 144883 files and directories currently installed.)
# Preparing to unpack libasan1_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking libasan1:amd64 (4.9.3-13ubuntu2) ...
# Setting up libasan1:amd64 (4.9.3-13ubuntu2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Selecting previously unselected package libgcc-4.9-dev:amd64.
# (Reading database ... 144886 files and directories currently installed.)
# Preparing to unpack libgcc-4.9-dev_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking libgcc-4.9-dev:amd64 (4.9.3-13ubuntu2) ...
# Setting up libgcc-4.9-dev:amd64 (4.9.3-13ubuntu2) ...
# Selecting previously unselected package cpp-4.9.
# (Reading database ... 145015 files and directories currently installed.)
# Preparing to unpack cpp-4.9_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking cpp-4.9 (4.9.3-13ubuntu2) ...
# Setting up cpp-4.9 (4.9.3-13ubuntu2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Selecting previously unselected package gcc-4.9.
# (Reading database ... 145024 files and directories currently installed.)
# Preparing to unpack gcc-4.9_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking gcc-4.9 (4.9.3-13ubuntu2) ...
# Setting up gcc-4.9 (4.9.3-13ubuntu2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Selecting previously unselected package libstdc++-4.9-dev:amd64.
# (Reading database ... 145070 files and directories currently installed.)
# Preparing to unpack libstdc++-4.9-dev_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking libstdc++-4.9-dev:amd64 (4.9.3-13ubuntu2) ...
# Setting up libstdc++-4.9-dev:amd64 (4.9.3-13ubuntu2) ...
# Selecting previously unselected package g++-4.9.
# (Reading database ... 145820 files and directories currently installed.)
# Preparing to unpack g++-4.9_4.9.3-13ubuntu2_amd64.deb ...
# Unpacking g++-4.9 (4.9.3-13ubuntu2) ...
# Setting up g++-4.9 (4.9.3-13ubuntu2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-4.9 100
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-7 50
# Out:
# update-alternatives: using /usr/bin/gcc-4.9 to provide /usr/bin/gcc (gcc) in auto mode

# %%
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-4.9 100
# Out:
# update-alternatives: using /usr/bin/g++-4.9 to provide /usr/bin/g++ (g++) in auto mode

# %%
# !sudo update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-7
# Out:
# update-alternatives: --install needs <link> <name> <path> <priority>
#
# Use 'update-alternatives --help' for program usage information.

# %%
# !update-alternatives --query gcc
# !update-alternatives --query g++
# Out:
# Name: gcc
# Link: /usr/bin/gcc
# Status: auto
# Best: /usr/bin/gcc-4.9
# Value: /usr/bin/gcc-4.9
#
# Alternative: /usr/bin/gcc-4.9
# Priority: 100
#
# Alternative: /usr/bin/gcc-7
# Priority: 50
# Name: g++
# Link: /usr/bin/g++
# Status: auto
# Best: /usr/bin/g++-4.9
# Value: /usr/bin/g++-4.9
#
# Alternative: /usr/bin/g++-4.9
# Priority: 100

# %%
# !gcc --version
# Out:
# gcc (Ubuntu 4.9.3-13ubuntu2) 4.9.3
# Copyright (C) 2015 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1raIzC3_QlztVxz0qtUNxrjGkhlKJuvjg' -O PAN_shufflenetv2_FPEM_FFM.pth
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1GKs-NnezTc6WN0P_Zw7h6wYzRRZdJFKl' -O PAN_resnet18_FPEM_FFM.pth
# Out:
# --2020-12-17 10:40:35--  https://docs.google.com/uc?export=download&id=1raIzC3_QlztVxz0qtUNxrjGkhlKJuvjg
# Resolving docs.google.com (docs.google.com)... 108.177.97.101, 108.177.97.100, 108.177.97.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.97.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m8e11t3o9ml5glbn0vvjnll8mrsdhia1/1608201600000/11121545197610971228/*/1raIzC3_QlztVxz0qtUNxrjGkhlKJuvjg?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-12-17 10:40:36--  https://doc-0k-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/m8e11t3o9ml5glbn0vvjnll8mrsdhia1/1608201600000/11121545197610971228/*/1raIzC3_QlztVxz0qtUNxrjGkhlKJuvjg?e=download
# Resolving doc-0k-ak-docs.googleusercontent.com (doc-0k-ak-docs.googleusercontent.com)... 64.233.188.132, 2404:6800:4008:c06::84
# Connecting to doc-0k-ak-docs.googleusercontent.com (doc-0k-ak-docs.googleusercontent.com)|64.233.188.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘PAN_shufflenetv2_FPEM_FFM.pth’
#
# PAN_shufflenetv2_FP     [   <=>              ]  18.95M  27.2MB/s    in 0.7s
#
# 2020-12-17 10:40:38 (27.2 MB/s) - ‘PAN_shufflenetv2_FPEM_FFM.pth’ saved [19866462]
#
# --2020-12-17 10:40:38--  https://docs.google.com/uc?export=download&id=1GKs-NnezTc6WN0P_Zw7h6wYzRRZdJFKl
# Resolving docs.google.com (docs.google.com)... 108.177.97.101, 108.177.97.100, 108.177.97.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.97.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘PAN_resnet18_FPEM_FFM.pth’
#
# PAN_resnet18_FPEM_F     [ <=>                ]   3.18K  --.-KB/s    in 0s
#
# 2020-12-17 10:40:38 (47.9 MB/s) - ‘PAN_resnet18_FPEM_FFM.pth’ saved [3254]

# %%
cd /content/PAN.pytorch
# Out:
# /content/PAN.pytorch

# %%
# !ls
# Out:
# base	     data_loader  __init__.py  post_processing	trainer
# config	     eval.py	  LICENSE.md   predict.py	train.py
# config.json  imgs	  models       README.MD	utils

# %%
# !pip install Polygon3
# Out:
# Collecting Polygon3
#   Downloading https://files.pythonhosted.org/packages/73/a0/d07a4f3e80ed7020a33f3111db217f54ac44a485ff45da3c21ce49f65041/Polygon3-3.0.8.tar.gz (71kB)
#      |████████████████████████████████| 71kB 3.6MB/s
# Building wheels for collected packages: Polygon3
#   Building wheel for Polygon3 (setup.py) ... done
#   Created wheel for Polygon3: filename=Polygon3-3.0.8-cp36-cp36m-linux_x86_64.whl size=101485 sha256=45c51261406a0739ad45c200294f52dd2f3f841d00a3d708a8175eee9d415c57
#   Stored in directory: /root/.cache/pip/wheels/95/32/f1/5525b233996d9d99cbce2f0a8da60d137ddddc555d3e8b0e2a
# Successfully built Polygon3
# Installing collected packages: Polygon3
# Successfully installed Polygon3-3.0.8

# %%
# dataset VNese
# !gdown https://drive.google.com/uc?id=1SdwlVVUSIP8xvYlE9uDLzuPFhrA8yMLg
# !unzip -qq val_vn.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SdwlVVUSIP8xvYlE9uDLzuPFhrA8yMLg
# To: /content/PAN.pytorch/val_vn.zip
# 9.72MB [00:00, 155MB/s]

# %%
# model SROIE
# !gdown https://drive.google.com/uc?id=1MJT1vYeG3QEkSdgrY08vZP2biGDpFIQo
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MJT1vYeG3QEkSdgrY08vZP2biGDpFIQo
# To: /content/PAN.pytorch/PANNet_model_pretrain_SOIRE.pth
# 185MB [00:00, 186MB/s]

# %%
# !mv -f /content/PAN.pytorch/base/ /content/
# !mv -f /content/PAN.pytorch/config/ /content/
# !mv -f /content/PAN.pytorch/imgs/ /content/
# !mv -f /content/PAN.pytorch/trainer/ /content/
# !mv -f /content/PAN.pytorch/data_loader/ /content/
# !mv -f /content/PAN.pytorch/config.json /content/
# !mv -f /content/PAN.pytorch/eval.py /content/
# !mv -f /content/PAN.pytorch/utils/ /content/

# %%
# !python predict.py
# Out:
# make: Entering directory '/content/PAN.pytorch/post_processing'
# make: 'pse.so' is up to date.
# make: Leaving directory '/content/PAN.pytorch/post_processing'
# device: cuda:0
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# 0.18018722534179688

# %%
# !zip -r /content/PANnet_predict_for_API_task1.zip /content/PAN.pytorch

# %%
# !cp -rf /content/PANnet_predict_for_API_task1.zip '/content/drive/My Drive/Colab Notebooks/OCR/Task1/API'

# %%
# -*- coding: utf-8 -*-
# @Time    : 2019/8/24 12:06
# @Author  : zhoujun
from google.colab.patches import cv2_imshow
import torch
from torchvision import transforms
import os
import cv2
import time

from models import get_model

from post_processing import decode

def decode_clip(preds, scale=1, threshold=0.7311, min_area=5):
    import pyclipper
    import numpy as np
    preds[:2, :, :] = torch.sigmoid(preds[:2, :, :])
    preds = preds.detach().cpu().numpy()
    text = preds[0] > threshold  # text
    kernel = (preds[1] > threshold) * text  # kernel

    label_num, label = cv2.connectedComponents(kernel.astype(np.uint8), connectivity=4)
    bbox_list = []
    for label_idx in range(1, label_num):
        points = np.array(np.where(label == label_idx)).transpose((1, 0))[:, ::-1]
        if points.shape[0] < min_area:
            continue
        rect = cv2.minAreaRect(points)
        poly = cv2.boxPoints(rect).astype(int)

        d_i = cv2.contourArea(poly) * 1.5 / cv2.arcLength(poly, True)
        pco = pyclipper.PyclipperOffset()
        pco.AddPath(poly, pyclipper.JT_ROUND, pyclipper.ET_CLOSEDPOLYGON)
        shrinked_poly = np.array(pco.Execute(d_i))
        if shrinked_poly.size == 0:
            continue
        rect = cv2.minAreaRect(shrinked_poly)
        shrinked_poly = cv2.boxPoints(rect).astype(int)
        if cv2.contourArea(shrinked_poly) < 800 / (scale * scale):
            continue

        bbox_list.append([shrinked_poly[1], shrinked_poly[2], shrinked_poly[3], shrinked_poly[0]])
    return label, np.array(bbox_list)


class Pytorch_model:
    def __init__(self, model_path, gpu_id=None):
        '''
        初始化pytorch模型
        :param model_path: 模型地址(可以是模型的参数或者参数和计算图一起保存的文件)
        :param gpu_id: 在哪一块gpu上运行
        '''
        self.gpu_id = gpu_id

        if self.gpu_id is not None and isinstance(self.gpu_id, int) and torch.cuda.is_available():
            self.device = torch.device("cuda:%s" % self.gpu_id)
        else:
            self.device = torch.device("cpu")
        print('device:', self.device)
        checkpoint = torch.load(model_path, map_location=self.device)

        config = checkpoint['config']
        config['arch']['args']['pretrained'] = False
        self.net = get_model(config)

        self.img_channel = config['data_loader']['args']['dataset']['img_channel']
        self.net.load_state_dict(checkpoint['state_dict'])
        self.net.to(self.device)
        self.net.eval()

    def predict(self, img: str, short_size: int = 736):
        '''
        对传入的图像进行预测，支持图像地址,opecv 读取图片，偏慢
        :param img: 图像地址
        :param is_numpy:
        :return:
        '''
        assert os.path.exists(img), 'file is not exists'
        img = cv2.imread(img)
        if self.img_channel == 3:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        h, w = img.shape[:2]
        scale = short_size / min(h, w)
        img = cv2.resize(img, None, fx=scale, fy=scale)
        # 将图片由(w,h)变为(1,img_channel,h,w)
        tensor = transforms.ToTensor()(img)
        tensor = tensor.unsqueeze_(0)

        tensor = tensor.to(self.device)
        with torch.no_grad():
            if str(self.device).__contains__('cuda'):
                torch.cuda.synchronize(self.device)
            start = time.time()
            preds = self.net(tensor)[0]
            if str(self.device).__contains__('cuda'):
                torch.cuda.synchronize(self.device)
            preds, boxes_list = decode(preds)
            scale = (preds.shape[1] / w, preds.shape[0] / h)
            if len(boxes_list):
                boxes_list = boxes_list / scale
            t = time.time() - start
        return preds, boxes_list, t


if __name__ == '__main__':
    import matplotlib.pyplot as plt
    from utils.util import show_img, draw_bbox

    os.environ['CUDA_VISIBLE_DEVICES'] = str('0')

    model_path = '/content/PAN.pytorch/PANNet_model_pretrain_SOIRE.pth'

    # img_id = 10
    # img_path = '/content/PAN.pytorch/imgs/example/img_{}.jpg'.format(img_id)
    img_path = '/content/PAN.pytorch/val_vn/(1)_resize.jpg'

    # 初始化网络
    model = Pytorch_model(model_path, gpu_id=0)
    preds, boxes_list, t = model.predict(img_path)
    print(boxes_list)
    print(t)
    show_img(preds)
    img = draw_bbox(cv2.imread(img_path)[:, :, ::-1], boxes_list)
    # show_img(img, color=True)
    # print('aaaa')
    # plt.show()
    # for i, box in enumerate(boxes_list):
    #   box = box.astype(int)
    #   cv2.imwrite('crop_%s.jpg' % time.time(), img_path[tuple(box[0]), tuple(box[1]), :])

    # print(boxes_list)
    cv2_imshow(img)
# Out:
# device: cuda:0
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# [[[ 103.77717391    0.        ]
#   [ 303.68478261    0.        ]
#   [ 303.68478261   14.74398547]
#   [ 103.77717391   14.74398547]]
#
#  [[ 102.60361501   27.78442416]
#   [ 102.89830697   10.18019356]
#   [ 295.72450771   13.40667358]
#   [ 295.42980741   31.01090418]]
#
#  [[  98.28469724   46.93876418]
#   [  98.55677829   27.68039805]
#   [ 301.60847904   30.54770074]
#   [ 301.33638133   49.80606687]]
#
#  [[ 121.74338212   63.85223292]
#   [ 121.82881687   45.48677735]
#   [ 275.89331171   46.20320723]
#   [ 275.80788529   64.56866281]]
#
#  [[  94.83201997   79.59060118]
#   [  95.16112419   60.61629561]
#   [ 302.35323068   64.20841892]
#   [ 302.02412647   83.18272449]]
#
#  [[  68.76607095   76.51817095]
#   [ 329.8760376    75.82937971]
#   [ 329.93794466   99.2858778 ]
#   [  68.82797801   99.97466904]]
#
# <PIL.Image.Image image mode=RGB size=402x1203 at 0x7F02BAD6BEB8>

# %%
# %cd /content/
# !gdown https://drive.google.com/uc?id=1SDWkv6b9FjxDGbwsPxue5vx1cJwY19eD
# ! unzip -qq sample_dataset_f2.zip

# https://drive.google.com/file/d/1iLFR7D4Flke6MrL6NDvFaeA-g2_00UCS/view?usp=sharing
# !gdown https://drive.google.com/uc?id=1iLFR7D4Flke6MrL6NDvFaeA-g2_00UCS
! unzip -qq counter_cutted_dataset.zip
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1iLFR7D4Flke6MrL6NDvFaeA-g2_00UCS
# To: /content/counter_cutted_dataset.zip
# 100% 775k/775k [00:00<00:00, 113MB/s]

# %%
from xml.dom import minidom
from os import path, replace, scandir, remove
import xml.etree.ElementTree as ET
import cv2


def notext(f):
    return path.splitext(f.name)[0]


raw_img = list(
    sorted(scandir('Images'), key=lambda f: f.name)
)
raw_label = list(
    sorted(scandir('Annotations_xml'), key=lambda f: f.name)
)

csv_files = [f for f in raw_label if f.name.endswith('xml')]
jpg_files = [f for f in raw_img if f.name.endswith('jpg')]

for i, (f_jpg, f_csv) in enumerate(zip(jpg_files, csv_files)):
    if notext(f_jpg) != notext(f_csv):
        raise ValueError('Raw data filenames mismatch')

    img = cv2.imread(f_jpg.path)
    xml_content = minidom.parse(f_csv.path)
    xmins = xml_content.getElementsByTagName('xmin')
    ymins = xml_content.getElementsByTagName('ymin')
    xmaxs = xml_content.getElementsByTagName('xmax')
    ymaxs = xml_content.getElementsByTagName('ymax')
    name = str(xml_content.getElementsByTagName('filename')[0].firstChild.data)
    print(name)
    for i in range(2):
        xmin = int(xmins[i].childNodes[0].data)
        ymin = int(ymins[i].childNodes[0].data)
        xmax = int(xmaxs[i].childNodes[0].data)
        ymax = int(ymaxs[i].childNodes[0].data)
        croped = img[ymin:ymax, xmin:xmax]

        if i == 1:
            electricity_meter = 'counter/'+str(i)+name
            cv2.imwrite(electricity_meter, croped)

# %%
# %cd /content/
# !gdown https://drive.google.com/uc?id=1XE_nmzWmJMNt2s1y4iwEeqqUIFGasGlZ
! unzip -qq -o data.zip
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1XE_nmzWmJMNt2s1y4iwEeqqUIFGasGlZ
# To: /content/data.zip
# 289MB [00:03, 82.8MB/s]

# %%
# !python ./PAN.pytorch/eval.py
# Out:
# make: Entering directory '/content/PAN.pytorch/post_processing'
# make: 'pse.so' is up to date.
# make: Leaving directory '/content/PAN.pytorch/post_processing'
# Traceback (most recent call last):
#   File "./PAN.pytorch/eval.py", line 52, in <module>
#     save_path = main(model_path, img_path, save_path, gpu_id=gpu_id)
#   File "./PAN.pytorch/eval.py", line 27, in main
#     img_paths = [os.path.join(img_folder, x) for x in os.listdir(img_folder)]
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/e/zj/dataset/icdar2015/test/img'

# %%
# !rm -rf ./output/

# %%
# !cp -rf ./output/ '/content/drive/My Drive/Colab Notebooks/OCR/Task1/'
