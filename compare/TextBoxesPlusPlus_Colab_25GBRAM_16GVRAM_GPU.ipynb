# %%
# !nvidia-smi
# Out:
# Fri Oct 23 10:02:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %tensorflow_version 1.14
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/lloydnguyen96/ML_TextBoxesPlusPlus.git
# Out:
# Cloning into 'ML_TextBoxesPlusPlus'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 34 (delta 6), reused 34 (delta 6), pack-reused 0
# Unpacking objects: 100% (34/34), done.

# %%
# %cd /content/ML_TextBoxesPlusPlus
# !pip install -r /content/ML_TextBoxesPlusPlus/requirements.txt
# Out:
# /content/ML_TextBoxesPlusPlus
# ...
#      |████████████████████████████████| 51kB 904kB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
# ...

# %%
# !pip install mkl-fft==1.0.0.17 mkl-random==1.0.0.8 protobuf==3.12.0

# %%
# !pip install pyBaiduPan
# Out:
# ...
#      |████████████████████████████████| 122kB 1.6MB/s
# ...
#      |████████████████████████████████| 13.7MB 10.1MB/s
# ...
#      |████████████████████████████████| 61kB 9.1MB/s
# ...
#   Created wheel for PyExecJS: filename=PyExecJS-1.5.1-cp36-none-any.whl size=14590 sha256=287a881c651b41c237ab4edb9e7373fcebb32f69c33d0190b05a0439d992d739
#   Stored in directory: /root/.cache/pip/wheels/43/25/28/52dd7a6c691b1551e3d4482f3f16ef630cc9f59cae99cd33ba
# Successfully built PyExecJS
# ...

# %%
# !BdPan -u ghostmaxxx1520 -P 0123456mymy
# Out:
# Error: no "view" mailcap rules found for type "image/jpeg"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening '/content/captcha.jpg'
# Input the captcha:cypc
# Error: no "view" mailcap rules found for type "image/jpeg"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# ...

# %%
# !BdPan
# Out:
# D   0.0B 2020-10-23T11:34:58 apps
# all done!

# %%
# !BdPan list /tesr/dataset
# Out:
# F 976.2M 2017-04-12T16:26:21 part1.zip
# F 1008.1M 2017-04-12T16:26:54 part2.zip
# F 950.9M 2017-04-12T15:23:19 part3.zip
# F   1.3G 2017-04-12T16:28:40 part4.zip
# all done!

# %%
# !BdPan download "/tesr/dataset/part1.zip" "/content"
# Out:
# 2020-10-23 12:34:58,464 - INFO: download /tesr/dataset/part1.zip to /content/part1.zip
# 2020-10-23 12:39:52,365 - ERROR: ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/response.py", line 362, in _error_catcher
#     yield
#   File "/usr/local/lib/python3.6/dist-packages/urllib3/response.py", line 444, in read
#     data = self._fp.read(amt)
#   File "/usr/lib/python3.6/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.6/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.6/ssl.py", line 874, in read
# ...
