# %%
# !git clone https://github.com/lvpengyuan/corner.git
# Out:
# Cloning into 'corner'...
# remote: Enumerating objects: 63, done.
# remote: Total 63 (delta 0), reused 0 (delta 0), pack-reused 63
# Unpacking objects: 100% (63/63), done.

# %%
# NVIDIA GPU, Ubuntu 14.04, Python2.7, CUDA8/9
# PyTorch 0.2.0_3
# !pip install python==2.7
# !conda install pytorch=0.2.0_3 cuda90 -c pytorch
# Out:
# ERROR: Could not find a version that satisfies the requirement python==2.7 (from versions: none)
# ERROR: No matching distribution found for python==2.7
# /bin/bash: conda: command not found

# %%
cd /content/corner
# Out:
# /content/corner

# %%
# !ls
# Out:
# data	 eval_all.py	     evaluate_msra.py  make.sh	  rpsroi_pooling  utils
# dssd.py  eval_multiscale.py  layers	       README.md  train.py

# %%
# !sh ./make.sh   or  cd rpsroi_pooling && python build.py
# Out:
# Compiling roi pooling kernels by nvcc...
# python3: can't open file 'build.py': [Errno 2] No such file or directory

# %%
# !python eval_all.py
# Out:
# Traceback (most recent call last):
#   File "eval_all.py", line 7, in <module>
#     from data import  train_cfg, cfg_768x1280, cfg_512x512, cfg_768x768, cfg_1280x1280, AnnotationTransform, ICDARDetection, detection_collate, TD500Detection, COCODetection
#   File "/content/corner/data/__init__.py", line 1, in <module>
#     from .icdar import ICDARDetection
#   File "/content/corner/data/icdar.py", line 11, in <module>
#     from utils import get_boxes, generate_gt
# ImportError: cannot import name 'get_boxes'
